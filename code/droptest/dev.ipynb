# %%
# %%bash
#
# echo '
# #include <stdio.h>
# #include <signal.h>
# #include <unistd.h>
# #include <stdlib.h>
#
# static void sig_fct1(int no);
#
# int main(int argc, const char * argv[])
# {
#
#     printf("Waiting for Startbutton for pump \n");
#     if(signal(SIGUSR1, sig_fct1) == SIG_ERR)
#     {
#         printf("Cant catch SIGUSR1\n");
#     }
#
#     while (1)
#         pause();
#     return 0;
# }
#
#
# static void sig_fct1(int no)
# {
#     printf("Module : Pump\n");
#     printf("Caught Signal\n");
#     exit(0);
#
# }
# ' >pump.c
# gcc -o pump pump.c

# %%
# %%bash
#
# echo '
# #include <stdio.h>
# #include <signal.h>
# #include <unistd.h>
# #include <stdlib.h>
#
# static void sig_fct1(int no);
#
# int main(int argc, const char * argv[])
# {
#
#     printf("Generator: waiting for desired pressure\n");
#     if(signal(SIGUSR1, sig_fct1) == SIG_ERR)
#     {
#         printf("Cant catch SIGUSR1\n");
#     }
#
#     while (1)
#         pause();
#     return 0;
# }
#
#
# static void sig_fct1(int no)
# {
#     printf("Module : Generator\n");
#     printf("Caught Signal\n");
#     exit(0);
#
# }
# ' >drivegen.c
# gcc -o drivegen drivegen.c

# %%
# %%bash
#
# echo '
# #include <stdio.h>
# #include <signal.h>
# #include <unistd.h>
# #include <stdlib.h>
#
# static void sig_fct1(int no);
#
# int main(int argc, const char * argv[])
# {
#
#     printf("Grip: waiting for Generator\n");
#     if(signal(SIGUSR1, sig_fct1) == SIG_ERR)
#     {
#         printf("Cant catch SIGUSR1\n");
#     }
#
#     while (1)
#         pause();
#     return 0;
# }
#
#
# static void sig_fct1(int no)
# {
#     printf("Module : Grip\n");
#     printf("Caught Signal\n");
#     exit(0);
#
# }
# ' >grip.c
# gcc -o grip grip.c

# %%
# %%bash
#
# echo '
# #include <stdio.h>
# #include <signal.h>
# #include <unistd.h>
# #include <stdlib.h>
#
# static void sig_fct1(int no);
#
# int main(int argc, const char * argv[])
# {
#
#     printf("Shot high speed camera: waiting for motion sensor\n");
#     if(signal(SIGUSR1, sig_fct1) == SIG_ERR)
#     {
#         printf("Cant catch SIGUSR1\n");
#     }
#
#     while (1)
#         pause();
#     return 0;
# }
#
#
# static void sig_fct1(int no)
# {
#     printf("Module : Highspeed camera\n");
#     printf("Caught Signal\n");
#     exit(0);
#
# }
# ' >shothpcamera.c
# gcc -o shothpcamera shothpcamera.c

# %%
# %%bash
#
# echo '
# #include <stdio.h>
# #include <signal.h>
# #include <unistd.h>
# #include <stdlib.h>
#
# static void sig_fct1(int no);
#
# int main(int argc, const char * argv[])
# {
#
#     printf("Close high speed camera: waiting for motion sensor\n");
#     if(signal(SIGUSR1, sig_fct1) == SIG_ERR)
#     {
#         printf("Cant catch SIGUSR1\n");
#     }
#
#     while (1)
#         pause();
#     return 0;
# }
#
#
# static void sig_fct1(int no)
# {
#     printf("Module : Close highspeed camera\n");
#     printf("Caught Signal\n");
#     exit(0);
#
# }
# ' >closehpcamera.c
# gcc -o closehpcamera closehpcamera.c

# %%
# %%bash
#
# echo '
# #include <stdio.h>
# #include <signal.h>
# #include <unistd.h>
# #include <stdlib.h>
#
# static void sig_fct1(int no);
#
# int main(int argc, const char * argv[])
# {
#
#     printf("Close camera: waiting for groundsensor\n");
#     if(signal(SIGUSR1, sig_fct1) == SIG_ERR)
#     {
#         printf("Cant catch SIGUSR1\n");
#     }
#
#     while (1)
#         pause();
#     return 0;
# }
#
#
# static void sig_fct1(int no)
# {
#     printf("Module : Close camera\n");
#     printf("Caught Signal\n");
#     exit(0);
#
# }
# ' >closecamera.c
# gcc -o closecamera closecamera.c

# %%
# %%bash
#
# echo '
#
# #!/bin/bash
#
# ./pump
# ./drivegen
# ./grip
# ./shothpcamera
# ./closehpcamera
# ./closecamera
#
#
# '>droptest.sh

# %%
# %%bash
#
# echo '
#
# #!/bin/bash
# sleep 1
# pkill -USR1 pump
# sleep 5
# pkill -USR1 drivegen
# sleep 5
# pkill -USR1 grip
# sleep 5
# pkill -USR1 shothpcamera
# sleep 5
# pkill -USR1 closehpcamera
# sleep 5
# pkill -USR1 closecamera
#
#
# '>testsignal.sh
